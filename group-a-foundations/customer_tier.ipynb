# %%
Customer_name="sameera"
total_spend=35000
                            #in python we should'nt use (,) in between numbers especially for currency

if total_spend>40000:
  Tier="Golden tier 1"
elif total_spend>20000:
  Tier="silver tier 2"
else :
  Tier="bronze tier 3"

print(f'Costomer name: {customer_name} | Tier: {tier} ')
# Out:
# Costomer name: sameera | Tier: silver tier 2
